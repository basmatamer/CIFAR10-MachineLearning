# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
epochs=np.arange(37)
trloss=[2.29,1.291902,0.801542,0.584764,0.439947,0.320257, 0.232055,0.176774,0.118619,0.083700,0.064884,0.060377
          ,0.048670,0.051856,0.046474, 0.046172,0.041721,0.038188,0.038392,0.037472 ,0.031695,0.033725,0.028405,
         0.033319, 0.029614,0.026550,0.027834,0.028742,0.022937,0.023807,0.026397 ,0.021948 ,0.021499,0.022475 ,
         0.028447,0.018471,0.017871]
plt.plot(epochs,trloss, '-')
plt.ylabel('Training loss')
plt.xlabel('epochs')
plt.show()

# %%
epochs=np.arange(37)
valloss=[2.29,0.938153,0.739852,0.743765,0.812740,0.827137,0.953784,0.963667,1.164159,1.224458,1.331687,1.184813,1.384061,1.301917,1.302652,1.335525,1.401151,1.370464,1.291533,1.347444,1.502753,1.342668,1.609778,1.417321,1.403442,1.467728,1.515651,1.514728,1.623325,1.573217,1.454125,1.516777,1.493661,1.584819,1.375451, 1.506087,1.567379]
plt.plot(epochs,valloss, '-')
plt.ylabel('Validation loss')
plt.xlabel('epochs')
plt.show()
